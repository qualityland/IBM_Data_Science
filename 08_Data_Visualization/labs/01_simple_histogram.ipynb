# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(10000)
# histogram with 100 bins
plt.hist(x, 100)
plt.title('Normal distribution woth $\mu=0, \sigma=1$')
plt.savefig('matplotlib_histogram.png')
plt.show()
