# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot(5, 5, 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# updates the active figure
plt.title('Plotting Example')
plt.ylabel('Y')
plt.xlabel('X')
# Out:
# Text(0.5, 23.52222222222222, 'X')
